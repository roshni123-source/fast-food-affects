# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np 
# import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# import dataset

# %%
df=pd.read_csv(r'data\fast_food_affectss.csv')
df.head()
# Out:
#              Name  Gender            Age  Weight?                     type  \
# 0      Esha Iqbal  Female  18 - 22 years       50  2 or 3 times in a month
# 1   Junaid Javed     Male  18 - 22 years       60   2 or 3 times in a week
# 2          Areeba  Female  18 - 22 years       42   2 or 3 times in a week
# 3       Zarghona   Female  22 - 26 years       46  2 or 3 times in a month
# 4  Roshni Mustafa  Female  22 - 26 years       45          after long time
#
#        local/brand       Ingre  type of patient    anxiety/depression  \
# 0             both       No one           other  not regular consumer
# 1  Local fast food       No one           other             sometimes
# 2            brand         Oily           other             sometimes
# 3  Local fast food         Oily           other             sometimes
# 4             both  High sodium           other             sometimes
#
#                headache  ... Mood swing craving of fast food   diarhea  \
# ...

# %% [markdown]
# Remove Un-necceasry column

# %%
df.drop('Name',axis=1,inplace=True)
df.head()
# Out:
#    Gender            Age  Weight?                     type      local/brand  \
# 0  Female  18 - 22 years       50  2 or 3 times in a month             both
# 1    Male  18 - 22 years       60   2 or 3 times in a week  Local fast food
# 2  Female  18 - 22 years       42   2 or 3 times in a week            brand
# 3  Female  22 - 26 years       46  2 or 3 times in a month  Local fast food
# 4  Female  22 - 26 years       45          after long time             both
#
#         Ingre  type of patient    anxiety/depression              headache  \
# 0       No one           other  not regular consumer  Not regular consumer
# 1       No one           other             sometimes                    No
# 2         Oily           other             sometimes                    No
# 3         Oily           other             sometimes                    No
# 4  High sodium           other             sometimes                   Yes
#
# ...

# %% [markdown]
# Convering categorical data into numerical data

# %%
# from gettext import install
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Weight?']=label.fit_transform(df['Weight?'])
df['local/brand']=label.fit_transform(df['local/brand'])
df['Ingre ']=label.fit_transform(df['Ingre '])
df['type of patient']=label.fit_transform(df['type of patient'])
df['anxiety/depression']=label.fit_transform(df['anxiety/depression'])
df['headache']=label.fit_transform(df['headache'])
df['acne problem']=label.fit_transform(df['acne problem'])
df['disease']=label.fit_transform(df['disease'])
df['muscle fatigue']=label.fit_transform(df['muscle fatigue'])
df['digestive issue']=label.fit_transform(df['digestive issue'])
df['Mood swing']=label.fit_transform(df['Mood swing'])
df['craving of fast food']=label.fit_transform(df['craving of fast food'])
df['diarhea']=label.fit_transform(df['diarhea'])
df['gastritis']=label.fit_transform(df['gastritis'])
df[' stomach']=label.fit_transform(df[' stomach'])
df[' vomit']=label.fit_transform(df[' vomit'])
df['agressive']=label.fit_transform(df['aggressive'])
df[' type_of_hunger?']=label.fit_transform(df[' type_of_hunger?'])
df['vitamins tablets']=label.fit_transform(df['vitamins tablets'])
df['fast food is healthy']=label.fit_transform(df['fast food is healthy'])
df['Gender']=label.fit_transform(df['Gender'])
df['Age']=label.fit_transform(df['Age'])
df['type']=label.fit_transform(df['type'])
df['aggressive']=label.fit_transform(df['aggressive'])
df.head()
# Out:
#    Gender  Age  Weight?  type  local/brand  Ingre   type of patient  \
# 0       0    1       10     1            1       2                3
# 1       1    1       20     2            0       2                3
# 2       0    1        4     2            2       3                3
# 3       0    2        6     1            0       3                3
# 4       0    2        5     4            1       0                3
#
#    anxiety/depression  headache  acne problem  ...  craving of fast food  \
# 0                   1         1             1  ...                     1
# 1                   2         0             0  ...                     0
# 2                   2         0             2  ...                     1
# 3                   2         0             1  ...                     0
# 4                   2         3             2  ...                     2
#
#    diarhea  gastritis   stomach   vomit  aggressive   type_of_hunger?  \
# ...

# %%
df.describe()
# Out:
#            Gender         Age     Weight?        type  local/brand  \
# count  119.000000  119.000000  119.000000  119.000000   119.000000
# mean     0.403361    1.436975   17.546218    1.974790     1.033613
# std      0.509558    0.879509    9.912967    1.153199     0.449723
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    1.000000   10.000000    1.000000     1.000000
# 50%      0.000000    1.000000   17.000000    2.000000     1.000000
# 75%      1.000000    2.000000   25.000000    3.000000     1.000000
# max      2.000000    4.000000   40.000000    4.000000     2.000000
#
#            Ingre   type of patient  anxiety/depression    headache  \
# count  119.000000       119.000000          119.000000  119.000000
# mean     2.563025         2.596639            1.109244    0.932773
# std      0.708767         0.762682            0.880966    1.006177
# min      0.000000         0.000000            0.000000    0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                119 non-null    int32
#  1   Age                   119 non-null    int32
#  2   Weight?               119 non-null    int64
#  3   type                  119 non-null    int32
#  4   local/brand           119 non-null    int32
#  5   Ingre                 119 non-null    int32
#  6   type of patient       119 non-null    int32
#  7   anxiety/depression    119 non-null    int32
#  8   headache              119 non-null    int32
#  9   acne problem          119 non-null    int32
#  10  disease               119 non-null    int32
#  11  muscle fatigue        119 non-null    int32
#  12  digestive issue       119 non-null    int32
#  13  Mood swing            119 non-null    int32
#  14  craving of fast food  119 non-null    int32
# ...

# %%
print("====total number of samples=====")
print(df.size)
print("====total number of rows and columns=====")
print(df.shape)
print("====maximum value=====")
print(df.max())
print("====minimum value=====")
print(df.min())
# Out:
# ====total number of samples=====
# 2856
# ====total number of rows and columns=====
# (119, 24)
# ====maximum value=====
# Gender                   2
# Age                      4
# Weight?                 40
# type                     4
# local/brand              2
# Ingre                    4
# type of patient          3
# anxiety/depression       3
# headache                 5
# acne problem             4
# disease                 47
# muscle fatigue           3
# digestive issue          3
# Mood swing               2
# craving of fast food     2
# diarhea                  3
# gastritis                3
#  stomach                 3
#  vomit                   2
# aggressive               4
#  type_of_hunger?         4
# vitamins tablets         2
# fast food is healthy     3
# agressive                4
# dtype: int64
# ====minimum value=====
# Gender                  0
# Age                     0
# Weight?                 0
# type                    0
# local/brand             0
# ...

# %%
df.nunique()
# Out:
# Gender                   3
# Age                      5
# Weight?                 41
# type                     5
# local/brand              3
# Ingre                    5
# type of patient          4
# anxiety/depression       4
# headache                 6
# acne problem             5
# disease                 48
# muscle fatigue           4
# digestive issue          4
# Mood swing               3
# craving of fast food     3
# diarhea                  4
# gastritis                4
#  stomach                 4
#  vomit                   3
# aggressive               5
#  type_of_hunger?         5
# vitamins tablets         3
# fast food is healthy     4
# agressive                5
# dtype: int64

# %%
import seaborn as sns
sns.histplot(df['headache'],kde=True)
# Out:
# <AxesSubplot:xlabel='headache', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
sns.boxplot(df['disease'])
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='disease'>

# %%
sns.scatterplot(x=df['local/brand'],y=df['headache'])
# Out:
# <AxesSubplot:xlabel='local/brand', ylabel='headache'>

# %%
plt.pie(df['fast food is healthy'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2820a4cbb50>,
# ...
#  [Text(1.0991624406920393, 0.04291769998402933, ''),
#   Text(1.0947687415257237, 0.10715130693642187, ''),
#   Text(1.0897545402588844, 0.14978331677843057, ''),
#   Text(1.0791247225851215, 0.21328345717749658, ''),
#   Text(1.0592090145724589, 0.2967764536624172, ''),
#   Text(1.0400316021024811, 0.358237723625174, ''),
#   Text(1.0172912125353002, 0.4184717301066574, ''),
#   Text(0.9910657507028897, 0.4772721213141597, ''),
#   Text(0.9815646599674245, 0.4965186988453049, ''),
#   Text(0.9815646599674245, 0.4965186988453049, ''),
#   Text(0.9614450607212205, 0.5344374567849532, ''),
#   Text(0.916846363806583, 0.6077768876607987, ''),
#   Text(0.8797175502204994, 0.6603764319189801, ''),
#   Text(0.8666649697670064, 0.6774155520644283, ''),
#   Text(0.8395749690939803, 0.7107136352081914, ''),
#   Text(0.8112064341844172, 0.7429294186783849, ''),
#   Text(0.796556142303176, 0.7586160505546153, ''),
# ...

# %%
sns.barplot(df['aggressive'])
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='aggressive'>

# %%
sns.violinplot(df['gastritis'],df['Gender'],color='c')
# Out:
# c:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gastritis', ylabel='Gender'>

# %%
x=df.drop('Age',axis=1)
y=df['Age']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)
x_train.shape
# Out:
# (95, 23)

# %%
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
# Out:
# 0.8421052631578947

# %%
y_pre=svc.predict(x_test)
svc.score(x_test,y_test)
# Out:
# 0.4583333333333333

# %%
from sklearn.metrics import accuracy_score
xy=accuracy_score(y_test,y_pred=y_pre)
xy
# Out:
# 0.4583333333333333
